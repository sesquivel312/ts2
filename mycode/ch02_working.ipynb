# %%
from pathlib import Path
import sys
sys.path.insert(0,'/mnt/c/Users/steve/dev/stats/ts2/code')
base = Path(r'/mnt/c/Users/steve/dev/stats/ts2/')  # setup to find data files
code = base.joinpath('code')
mycode = base.joinpath('mycode')
print(sys.path)
# Out:
# ['/mnt/c/Users/steve/dev/stats/ts2/code', '/mnt/c/Users/steve/dev/stats/ts2/mycode', '/usr/local/lib/python38.zip', '/usr/local/lib/python3.8', '/usr/local/lib/python3.8/lib-dynload', '', '/mnt/c/Users/steve/dev/stats/ts2/env/nix/lib/python3.8/site-packages', '/mnt/c/Users/steve/dev/stats/ts2/env/nix/lib/python3.8/site-packages/IPython/extensions', '/home/steve/.ipython']

# %%
import pandas as pd
import nsfg
import thinkstats2 as ts
import thinkplot as tp

# %%
pdct = code.joinpath('2002FemPreg.dct')
pdat = code.joinpath('2002FemPreg.dat.gz')
preg = nsfg.ReadFemPreg(dct_file=pdct, dat_file=pdat)
preg
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN       6.0
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 2           2         1        NaN        NaN       NaN       NaN       5.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# ...       ...       ...        ...        ...       ...       ...       ...
# 13588   12571         1        NaN        NaN       NaN       NaN       6.0
# 13589   12571         2        NaN        NaN       NaN       NaN       3.0
# 13590   12571         3        NaN        NaN       NaN       NaN       3.0
# 13591   12571         4        NaN        NaN       NaN       NaN       6.0
# 13592   12571         5        NaN        NaN       NaN       NaN       6.0
#
# ...

# %%
preg.pregordr.value_counts().sort_index()
# Out:
# 1     5033
# 2     3766
# 3     2334
# 4     1224
# 5      613
# 6      308
# 7      158
# 8       78
# 9       38
# 10      17
# 11       8
# 12       5
# 13       3
# 14       3
# 15       1
# 16       1
# 17       1
# 18       1
# 19       1
# Name: pregordr, dtype: int64

# %%
first = preg[preg.pregordr == 1]
first
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN       6.0
# 2           2         1        NaN        NaN       NaN       NaN       5.0
# 5           6         1        NaN        NaN       NaN       NaN       6.0
# 8           7         1        NaN        NaN       NaN       NaN       5.0
# 10         12         1        NaN        NaN       NaN       NaN       5.0
# ...       ...       ...        ...        ...       ...       ...       ...
# 13578   12566         1        NaN        NaN       NaN       NaN       6.0
# 13580   12568         1        NaN        NaN       NaN       NaN       1.0
# 13583   12569         1        NaN        NaN       NaN       NaN       3.0
# 13585   12570         1        NaN        NaN       NaN       NaN       3.0
# 13588   12571         1        NaN        NaN       NaN       NaN       6.0
#
# ...

# %%
other = preg[preg.pregordr > 1]
other
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# 6           6         2        NaN        NaN       NaN       NaN       6.0
# 7           6         3        NaN        NaN       NaN       NaN       6.0
# ...       ...       ...        ...        ...       ...       ...       ...
# 13587   12570         3        NaN        NaN       NaN       NaN       3.0
# 13589   12571         2        NaN        NaN       NaN       NaN       3.0
# 13590   12571         3        NaN        NaN       NaN       NaN       3.0
# 13591   12571         4        NaN        NaN       NaN       NaN       6.0
# 13592   12571         5        NaN        NaN       NaN       NaN       6.0
#
# ...

# %%
w_first = first.totalwgt_lb
w_other = other.totalwgt_lb

# %%
ts.CohenEffectSize(w_first, w_other)
# Out:
# -0.06911825348820952

# %%
l_first = first.prglngth
l_other = other.prglngth

# %%
ts.CohenEffectSize(l_first, l_other)
# Out:
# -0.03131178583370326

# %%
tp.matplotlib.pyplot.xlim(6,9)
tp.Hist(ts.Hist(w_first))
tp.Show()

# %%
other
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# 6           6         2        NaN        NaN       NaN       NaN       6.0
# 7           6         3        NaN        NaN       NaN       NaN       6.0
# ...       ...       ...        ...        ...       ...       ...       ...
# 13587   12570         3        NaN        NaN       NaN       NaN       3.0
# 13589   12571         2        NaN        NaN       NaN       NaN       3.0
# 13590   12571         3        NaN        NaN       NaN       NaN       3.0
# 13591   12571         4        NaN        NaN       NaN       NaN       6.0
# 13592   12571         5        NaN        NaN       NaN       NaN       6.0
#
# ...

# %%
prime = pd.DataFrame(other, )
prime
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# 6           6         2        NaN        NaN       NaN       NaN       6.0
# 7           6         3        NaN        NaN       NaN       NaN       6.0
# ...       ...       ...        ...        ...       ...       ...       ...
# 13587   12570         3        NaN        NaN       NaN       NaN       3.0
# 13589   12571         2        NaN        NaN       NaN       NaN       3.0
# 13590   12571         3        NaN        NaN       NaN       NaN       3.0
# 13591   12571         4        NaN        NaN       NaN       NaN       6.0
# 13592   12571         5        NaN        NaN       NaN       NaN       6.0
#
# ...

# %%
import numpy as np
df = pd.DataFrame(np.random.randn(4,2))
df
# Out:
#           0         1
# 0 -0.858528 -0.582479
# 1 -0.698382  0.159446
# 2 -0.625795  0.973076
# 3  1.177856  0.156558

# %%
df.columns = ['one', 'two']
df
# Out:
#         one       two
# 0 -0.858528 -0.582479
# 1 -0.698382  0.159446
# 2 -0.625795  0.973076
# 3  1.177856  0.156558

# %%
df.index = ['row1', 'row2', 'row3', 'row4']
df
# Out:
#            one       two
# row1 -0.858528 -0.582479
# row2 -0.698382  0.159446
# row3 -0.625795  0.973076
# row4  1.177856  0.156558

# %%
df.loc['row2']
# Out:
# one   -0.698382
# two    0.159446
# Name: row2, dtype: float64

# %%
df.iloc[-1]
# Out:
# one    1.177856
# two    0.156558
# Name: row4, dtype: float64
